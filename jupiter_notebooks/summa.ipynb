# %%
from RL_GoBot.model import GoBot
from torchinfo import summary
from RL_GoBot import var

net = GoBot()

summary(
    net,
    input_size=(1, 6, var.BOARD_SIZE, var.BOARD_SIZE),  # batch_size=1
    device="cpu"
)
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# GoBot                                    [1, 83]                   --
# ├─Conv2d: 1-1                            [1, 30, 9, 9]             3,030
# ├─Conv2d: 1-2                            [1, 40, 9, 9]             30,040
# ├─Linear: 1-3                            [1, 150]                  96,150
# ├─Linear: 1-4                            [1, 110]                  16,610
# ├─Linear: 1-5                            [1, 83]                   9,213
# ...
# Total params: 155,043
# Trainable params: 155,043
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 2.80
# ...
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.05
# Params size (MB): 0.62
# Estimated Total Size (MB): 0.67
# ...
